# %% [markdown]
# # Multithreaded Rsync Test

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import sys
import glob
import re
import warnings
import logging

# Reload changed modules every time
# %load_ext autoreload
# %autoreload 2

# %%
sys.path.insert(0, '/tmp/hxm471/mtvss/')
import constants as const
sys.path.insert(0, '/tmp/hxm471/mtvss/pipeline_stage1')
import run_pipeline_stage1
from data import Data
from model import Model
sys.path.insert(0, '/tmp/hxm471/inaSpeechSegmenter/')
from segmenter import Segmenter
# Out:
# 2022-07-06 06:36:58.091167: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# !rsync -version
# Out:
# rsync  version 3.1.3  protocol version 31
# Copyright (C) 1996-2018 by Andrew Tridgell, Wayne Davison, and others.
# Web site: http://rsync.samba.org/
# Capabilities:
#     64-bit files, 64-bit inums, 64-bit timestamps, 64-bit long ints,
#     socketpairs, hardlinks, symlinks, IPv6, batchfiles, inplace,
#     append, ACLs, xattrs, iconv, symtimes, prealloc
#
# rsync comes with ABSOLUTELY NO WARRANTY.  This is free software, and you
# are welcome to redistribute it under certain conditions.  See the GNU
# General Public Licence for details.
#
# rsync is a file transfer program capable of efficient remote update
# via a fast differencing algorithm.
#
# Usage: rsync [OPTION]... SRC [SRC]... DEST
#   or   rsync [OPTION]... SRC [SRC]... [USER@]HOST:DEST
#   or   rsync [OPTION]... SRC [SRC]... [USER@]HOST::DEST
#   or   rsync [OPTION]... SRC [SRC]... rsync://[USER@]HOST[:PORT]/DEST
#   or   rsync [OPTION]... [USER@]HOST:SRC [DEST]
#   or   rsync [OPTION]... [USER@]HOST::SRC [DEST]
# ...

# %%
"hpc3:"+str('/mnt/rds/redhen/gallina/Rosenthal/2006/2006-12/2006-12-11/2006-12-11_0000_US_00018530_V1_VHS23_MB22_E1_NV.mp4')
# Out:
# 'hpc3:/mnt/rds/redhen/gallina/Rosenthal/2006/2006-12/2006-12-11/2006-12-11_0000_US_00018530_V1_VHS23_MB22_E1_NV.mp4'

# %%
run_pipeline_stage1.main(50,True)
# Out:
# +++ Step 1: Data ingestion +++
#
# ['/mnt/rds/redhen/gallina/Rosenthal/2003/2003-03/2003-03-17/2003-03-17_0000_US_00026407_V3_VHSP20_MB23_H4_NC.mp4'
#  '/mnt/rds/redhen/gallina/Rosenthal/2003/2003-03/2003-03-17/2003-03-17_0000_US_00026407_V3_VHS37_MB22_H37_DV_BE.mp4'
#  '/mnt/rds/redhen/gallina/Rosenthal/2003/2003-03/2003-03-04/2003-03-04_0000_US_00009143_V2_VHS50_MB20_H17_AK.mp4'
#  '/mnt/rds/redhen/gallina/Rosenthal/2003/2003-03/2003-03-04/2003-03-04_0000_US_00009143_V2_VHS16_MB13_H15_DJ.mp4'
#  '/mnt/rds/redhen/gallina/Rosenthal/2003/2003-03/2003-03-04/2003-03-04_0000_US_00009144_V3_VHSP14_MB21_H9_JP.mp4'
#  '/mnt/rds/redhen/gallina/Rosenthal/2003/2003-03/2003-03-03/2003-03-03_0000_US_00018592_V3_VHS35_MB41_H26_AK_BE.mp4'
#  '/mnt/rds/redhen/gallina/Rosenthal/2003/2003-03/2003-03-03/2003-03-03_0000_US_00018588_V1_VHS23_MB22_E1_NV.mp4'
#  '/mnt/rds/redhen/gallina/Rosenthal/2003/2003-03/2003-03-03/2003-03-03_0000_US_00018592_V3_VHS42_MB6_H20_GS.mp4'
# ...
