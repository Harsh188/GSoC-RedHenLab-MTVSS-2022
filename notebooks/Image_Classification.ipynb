# %% [markdown]
# # ResNet50V2 Image Classifier

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2
from IPython.display import display, clear_output
from PIL import Image
from IPython.display import SVG

import os
import sys
import glob
import warnings
import random

# %load_ext autoreload
# %autoreload 2

# %%
sys.path.insert(0, '/mnt/rds/redhen/gallina/home/hxm471/RedHenLab-Multimodal_TV_Show_Segmentation/mtvss/')
import constants as const

# %%
model_output_path = const.SCRATCH_PATH+'model_output'

# %%
loss_plt = SVG(model_output_path+'/pretrainedResNet50V2_LossPlots.svg')
loss_plt

# %%
acc_plt = SVG(model_output_path+'/pretrainedResNet50V2_AccuracyPlots.svg')
acc_plt
